# %%
sekil  =   input ( "Hangi şeklin tipini öğrenmek?" )

if  ( sekil  ==  "Dörtgen" ): 
    print ( "Lütfen adreslerini bölgeye giriniz." ) 
    a  =  int ( input ( "Kenar-1:" )) 
    b  =  int ( input ( "Kenar-2:" )) 
    c  =  int ( input ( "Kenar-3:" )) 
    d  =  int ( input ( "Kenar-4:" ))
    
    if  ( a  ==  b  and  a  ==  c  and  a  ==  d ): 
        print ( "Kare" ) 
    elif  ( a  ==  c  and  b  ==  d ): 
        print ( "Dikdörtgen" ) 
    else : 
        print ( "Dörtgen" )
        
    
    
elif  ( sekil  ==  "Üçgen" ): 
    a  =  int ( input ( "Kenar-1:" )) 
    b  =  int ( input ( "Kenar-2:" )) 
    c  =  int ( input ( "Kenar-3:" )) 
    if  (  abs ( a + b )  >  c  and  abs ( a + c )  >  b  and  abs ( b + c ) >  a ): 
        if  ( a  ==  b  and  a  ==  c  ): 
            print ( "Eşkenar Üçgen..." ) 
        elif  (( a  ==  b  and  a  !=  c )  or ( a  ==  c  and a  !=  b )  or  ( b  ==  c and b  !=  a )): 
            print ( "İkizkenar Üçgen...." ) 
        else : 
            print ("Çeşitkenar Üçgen..." ) 
    else : 
        print ( "Üçgen belirtmiyor..." )
        
else : 
    print ( "Geçersiz Şekil..." )

# %%
print("üçgen için : 1")
print("dörtgen için : 2")
s = int(input("sayı giriniz (1/2): "))
if (s == 2) :
    a = float(abs(input("1. kenarı giriniz: ")))
    b = float(abs(input("2. kenarı giriniz: ")))
    c = float(abs(input("3. kenarı giriniz: ")))
    d = float(abs(input("4. kenarı giriniz: ")))
    if (a == b and a == c and a == d):
        print("kare")
    elif(a == c and b == d ):
        print("dikdörtgen")
    else:
        print("dağınık")
elif (s == 1) :
    a = float(input("1. kenarı giriniz: "))
    b = float(input("2. kenarı giriniz: "))
    c = float(input("3. kenarı giriniz: "))
    if   ( a + b )  >  c  and  ( a + c )  >  b  and  ( b + c ) >  a : 
        if  ( a  ==  b  and  a  ==  c  ): 
            print ( "Eşkenar Üçgen..." ) 
        elif  (( a  ==  b  and  a  !=  c )  or  ( a  ==  c  and  a  !=  b )  or  ( b  ==  c  and b  !=  a )): 
            print ( "İkizkenar Üçgen...." ) 
        else : 
            print ("Çeşitkenar Üçgen..." )
    else:
        print("üçgen belirtmşyor")
    
else:
    print("geçersiz şekil")

# %%
k = float(input("kilo giriniz: "))
b = float(input("boy giriniz: "))
e = k / (b * b)
if e < 18.5 :
    print(f"boy-kilo endexsiniz : {e} zayıfsınız")
elif 18.5 <= e <25 :
    print(f"boy-kilo endexsiniz : {e} normalsınz")
elif 25 <= e <30 :
    print(f"boy-kilo endexsiniz : {e} fazla kilolusunuz")
else: 
    print(f"boy-kilo endexsiniz : {e} obezsiniz")

# %%
1 <= 1

# %%
a = float(input("1. sayıyı giriniz: "))
b = float(input("2. sayıyı giriniz: "))
c = float(input("3. sayıyı giriniz: "))
list = [a,b,c]
e = list.sort[-1]
print(f"en büyük sayı{e}")

# %%
a = float(input("1. sayıyı giriniz: "))
b = float(input("2. sayıyı giriniz: "))
c = float(input("3. sayıyı giriniz: "))
list = [a,b,c]

print(list)

# %%
list = (5.0, 4.0, 7.0)
print(list.sort)

# %%
1 =< 1

# %%
a = int(input("birinci:"))
b = int(input("ikinci: "))
c = int(input("üçüncü: "))
print("toplamları:", a+b+c)

# %%
a = int(input("birinci sayı: "))
b = int(input("ikinci sayı: "))
c = int(input("üçüncü sayı: "))
print(f"toplamları: {a+b+c}")

# %%
a = int(input("kaç km gittniz:"))
b = int(input("km başı kaç lt yakıyorsunuz:"))
c = int(input("lt fiyatı giriniz:"))
print(f"masrafınız: {a*c*b}")

# %%
a = input("adnız:")
b = input("soyadınz: ")
c = int(input("numaranız: "))
print(f"adı:{a}\nsoyadı:{b}\nnumara:{c}")

# %%
a = int(input("sayi1: "))
b = int(input("sayi2: "))
a,b = b,a
print(f"birinci sayı: {a}\n ikinci sayi:{b}")

# %%
a  =  int (input( "a:" )) 
b  =  int (input( "b:" )) 
c  =  int (input( "c:" ))

çarpışma  =  a  *  b  *  c

print ( " {} x {} x {} = {} dir" . format ( a , b , c , çarpışma ))

# %%
"a" < "b "

# %%
a = int(input("sayı giriniz:"))
if a < 0:
    print("sayınız negatif")
elif a == 0:
    print("sayınız nötr")
else:
    print("sayınız pozitif")
