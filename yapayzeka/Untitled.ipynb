# %%
print("üçgen için : 1")
print("dörtgen için : 2")
a = int(input("sayı giriniz (1/2): "))
if (a == 2) :
    a = float(abs(input("1. kenarı giriniz: ")))
    b = float(abs(input("2. kenarı giriniz: ")))
    c = float(abs(input("3. kenarı giriniz: ")))
    d = float(abs(input("4. kenarı giriniz: ")))
    if (a == b and a == c and a == d):
        print("kare")
    elif(a == c and b == d ):
        print("dikdörtgen")
    else:
        print("dağınık")
elif (a == 1) :
    b = float(input("1. kenarı giriniz: "))
    i = float(input("2. kenarı giriniz: "))
    u = float(input("3. kenarı giriniz: "))
    if   ( a + b )  >  c  and  ( a + c )  >  b  and  ( b + c ) >  a : 
        if  ( a  ==  b  and  a  ==  c  ): 
            print ( "Eşkenar Üçgen..." ) 
        elif  (( a  ==  b  and  a  !=  c )  or  ( a  ==  c  and  a  !=  b )  or  ( b  ==  c  and b  !=  a )): 
            print ( "İkizkenar Üçgen...." ) 
        else : 
            print ("Çeşitkenar Üçgen..." )
    else:
        print("üçgen belirtmşyor")
    
else:
    print("geçersiz şekil")
# Out:
# üçgen için : 1
# dörtgen için : 2
# sayı giriniz (1/2): 1
# 1. kenarı giriniz: 5
# 2. kenarı giriniz: 5
# 3. kenarı giriniz: 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30724\386433761.py in <module>
#      17     i = float(input("2. kenarı giriniz: "))
#      18     u = float(input("3. kenarı giriniz: "))
# ---> 19     if   ( a + b )  >  c  and  ( a + c )  >  b  and  ( b + c ) >  a :
#      20         if  ( a  ==  b  and  a  ==  c  ):
#      21             print ( "Eşkenar Üçgen..." )
#
# NameError: name 'c' is not defined
