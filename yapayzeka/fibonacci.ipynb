# %%
a = 1
b = 1
fibonacci = [a,b]
for i in range(1000):
    a,b = b, a+ b
    fibonacci.append(b)
    d = len(str(fibonacci[-1]))
print(d)

# %%
print(len(str(fibonacci[-1])))

# %%
a = len("113796925398360272257523782552224175572745930353730513145086634176691092536145985470146129334641866902783673042322088625863396052888690096969577173696370562180400527049497109023054114771394568040040412172632376")

print(a)

# %%
print(*range(1,5))

# %%
sayi = 5
for i in range(1,sayi + 5):
    
    print(i)

# %%
sayi =  int ( input ( "Sayı:" ))

i  =  1 
toplam  =  0 
while  ( i  <  sayi ): 
    if  ( sayi  %  i  ==  0 ): 
        toplam  +=  i 
        i += 1
    else:
        i += 1
        
    

if  ( toplam  ==  sayi ): 
    print ( sayi , "mükemmel bir sayıdır." ) 
else : 
    print ( sayi , "mükemmel bir sayı değildir." )

# %%
sayi = input("sayı giriniz: ")
basamaksayisi = len(sayi)
sayi1 = int(sayi)
liste = sayi[0:basamaksayisi - 1]
print(liste)

# %%
sayi = input("sayı giriniz: ")
print(sayi)
