# %%
sayi = int(input("sayı giriniz: "))
k = 1
liste = []
while k < sayi:
    
    if sayi % k == 0:
        liste.append(k)
    k += 1
    
    
    
if sayi == sum(liste):
    print("sayınız {} mükemmel sayıdır".format(sayi))
else:
    print("sayınız {} mükemmel sayı değildir".format(sayi))
# Out:
# sayı giriniz: 45
# sayınız 45 mükemmel sayı değildir

# %%
sayi(x,y) = int(input("iki tane sayı giriniz: "))
print(sayi)
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_70364\2807046542.py", line 1
#     sayi(x,y) = int(input("iki tane sayı giriniz: "))
#     ^
# SyntaxError: cannot assign to function call

# %%
def mukemmel(sayi):
    toplam = 0
    for i in range(1,sayi):
        if (sayi % i == 0):
            toplam += i
    while toplam == sayi
for i in range (1,1001):
    if ()
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_70364\3392866450.py", line 6
#     while toplam == sayi
#                         ^
# SyntaxError: invalid syntax

# %%
sayi = int(input("sayı giriniz: "))
liste = []
for i in range(1,sayi + 1):
    liste.append(i)
print(liste)

# %%
def mukemmelsayi(sayi):
    toplam = 0
    k = 1
    for i in range(1,sayi + 1):
        while k <= i:
            if i % k == 0:
                toplam += k
                if toplam == sayi:
                    print("mükemmel sayi")
                else:
                    print("mükemmel sayi değildir")
            else:
                continue
        k += 1
print(mukemmelsayi())

# %%
def  mukemmel ( sayi ):
    
    toplam  =  0
    for i in range( 1 , sayi ) :
        
        if  ( sayi  %  i  ==  0 ): 
            toplam  +=  i
            
    while  toplamı  ==  sayi


for i in range( 1 , 1001 ): if ( mukemmel ( i )): print ( " Mükemmel Sayı:" , i )
