# %%
liste = [(3,4),(10,3),(5,6),(1,9)]
def carpma(x,y):
    return x * y
for x,y in liste:
    return

# %%
liste = [(3,4),(10,3),(5,6),(1,9)]
list(map(lambda x,y: x * y, ))

# %%
def carpma(tupple ):
    return tupple[0] * tupple[1]
    
liste = [(3,4),(10,3),(5,6),(1,9)]
print(list(map(carpma,liste)))
# Out:
# [12, 30, 30, 9]
